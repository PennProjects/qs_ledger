# %% [markdown]
# ## Apple Health Processor

# %% [markdown]
# -----

# %% [markdown]
# ## Dependencies and Libraries

# %%
from datetime import date, datetime, timedelta as td
import pytz
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib notebook

# %% [markdown]
# ------

# %% [markdown]
# ## Functions for Processing Dates and Timezones

# %%
# functions to convert UTC to Shanghai time zone and extract date/time elements
convert_tz = lambda x: x.to_pydatetime().replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Eastern'))
get_year = lambda x: convert_tz(x).year
get_month = lambda x: '{}-{:02}'.format(convert_tz(x).year, convert_tz(x).month) #inefficient
get_date = lambda x: '{}-{:02}-{:02}'.format(convert_tz(x).year, convert_tz(x).month, convert_tz(x).day) #inefficient
get_day = lambda x: convert_tz(x).day
get_hour = lambda x: convert_tz(x).hour
get_minute = lambda x: convert_tz(x).minute
get_day_of_week = lambda x: convert_tz(x).weekday()

# %% [markdown]
# ---

# %% [markdown]
# ## Steps

# %%
steps = pd.read_csv("data/StepCount.csv")

# %%
steps.tail()
# Out:
#                  sourceName sourceVersion  \
# 221537  Akash’s Apple Watch           7.6
# 221538  Akash’s Apple Watch           7.6
# 221539       Akash's iPhone          14.6
# 221540  Akash’s Apple Watch           7.6
# 221541  Akash’s Apple Watch           7.6
#
#                                                    device       type   unit  \
# 221537  <<HKDevice: 0x281845d10>, name:Apple Watch, ma...  StepCount  count
# 221538  <<HKDevice: 0x281845d10>, name:Apple Watch, ma...  StepCount  count
# 221539  <<HKDevice: 0x281846ee0>, name:iPhone, manufac...  StepCount  count
# 221540  <<HKDevice: 0x281845d10>, name:Apple Watch, ma...  StepCount  count
# 221541  <<HKDevice: 0x281845d10>, name:Apple Watch, ma...  StepCount  count
#
#                      creationDate                  startDate  \
# 221537  2021-07-21 14:45:03 -0400  2021-07-21 14:39:47 -0400
# 221538  2021-07-21 14:45:03 -0400  2021-07-21 14:40:49 -0400
# 221539  2021-07-21 15:17:42 -0400  2021-07-21 15:05:50 -0400
# 221540  2021-07-21 15:05:42 -0400  2021-07-21 15:04:02 -0400
# 221541  2021-07-21 15:16:38 -0400  2021-07-21 15:05:50 -0400
#
#                           endDate  value
# 221537  2021-07-21 14:39:50 -0400      8
# 221538  2021-07-21 14:41:15 -0400     36
# 221539  2021-07-21 15:06:03 -0400     29
# 221540  2021-07-21 15:04:05 -0400      6
# 221541  2021-07-21 15:15:16 -0400     33

# %%
# parse out date and time elements as Shanghai time
steps['startDate'] = pd.to_datetime(steps['startDate'])
steps['year'] = steps['startDate'].map(get_year)
steps['month'] = steps['startDate'].map(get_month)
steps['date'] = steps['startDate'].map(get_date)
steps['day'] = steps['startDate'].map(get_day)
steps['hour'] = steps['startDate'].map(get_hour)
steps['dow'] = steps['startDate'].map(get_day_of_week)

# %%
steps.head()
# Out:
#        sourceName sourceVersion  \
# 0  Akash's iPhone         9.3.1
# 1  Akash's iPhone         9.3.1
# 2  Akash's iPhone         9.3.1
# 3  Akash's iPhone         9.3.1
# 4  Akash's iPhone         9.3.1
#
#                                               device       type   unit  \
# 0  <<HKDevice: 0x281845c20>, name:iPhone, manufac...  StepCount  count
# 1  <<HKDevice: 0x281845c20>, name:iPhone, manufac...  StepCount  count
# 2  <<HKDevice: 0x281845c20>, name:iPhone, manufac...  StepCount  count
# 3  <<HKDevice: 0x281845c20>, name:iPhone, manufac...  StepCount  count
# 4  <<HKDevice: 0x281845c20>, name:iPhone, manufac...  StepCount  count
#
#                 creationDate                 startDate  \
# 0  2016-06-23 00:28:33 -0400 2016-06-22 15:42:34-04:00
# 1  2016-06-23 00:28:33 -0400 2016-06-22 15:52:35-04:00
# 2  2016-06-23 00:28:33 -0400 2016-06-22 16:07:25-04:00
# 3  2016-06-23 00:28:33 -0400 2016-06-22 16:21:12-04:00
# 4  2016-06-23 00:28:33 -0400 2016-06-22 16:34:16-04:00
#
#                      endDate  value  year    month        date  day  hour  dow
# 0  2016-06-22 15:44:10 -0400     72  2016  2016-06  2016-06-22   22    11    2
# 1  2016-06-22 15:55:59 -0400     80  2016  2016-06  2016-06-22   22    11    2
# 2  2016-06-22 16:07:43 -0400     20  2016  2016-06  2016-06-22   22    12    2
# 3  2016-06-22 16:25:56 -0400    150  2016  2016-06  2016-06-22   22    12    2
# 4  2016-06-22 16:40:08 -0400     18  2016  2016-06  2016-06-22   22    12    2

# %%
steps.columns
# Out:
# Index(['sourceName', 'sourceVersion', 'device', 'type', 'unit', 'creationDate',
#        'startDate', 'endDate', 'value', 'year', 'month', 'date', 'day', 'hour',
#        'dow'],
#       dtype='object')

# %%
steps_by_date = steps.groupby(['date'])['value'].sum().reset_index(name='Steps')

# %%
steps_by_date.tail()
# Out:
#             date  Steps
# 1845  2021-07-17  16726
# 1846  2021-07-18  55201
# 1847  2021-07-19  19883
# 1848  2021-07-20  20165
# 1849  2021-07-21   7016

# %%
# steps_by_date.tail(10)
steps_by_date.to_csv("data/steps_per_day.csv", index=False)

# %% [markdown]
# -----

# %% [markdown]
# ### Use Only Watch Steps, Remove Phone Steps

# %%
steps_device_by_year = steps.groupby(['year', 'sourceName'])['value'].sum().reset_index(name='Steps')

# %%
steps_device_by_year
# Out:
#     year           sourceName    Steps
# 0   2016       Akash's iPhone  1491191
# 1   2016  Akash’s Apple Watch  1269569
# 2   2017       Akash's iPhone  3347787
# 3   2017  Akash’s Apple Watch  2746328
# 4   2018       Akash's iPhone  3723920
# 5   2018  Akash’s Apple Watch  2473320
# 6   2019       Akash's iPhone  3627761
# 7   2019  Akash’s Apple Watch  2790222
# 8   2020       Akash's iPhone  1978617
# 9   2020  Akash’s Apple Watch  1849549
# 10  2021       Akash's iPhone  1422905
# 11  2021  Akash’s Apple Watch  1460839

# %%
steps.sourceName.unique()
# Out:
# array(["Akash's iPhone", 'Akash’s Apple\xa0Watch'], dtype=object)

# %%
# drop phone steps
steps = steps[steps.sourceName == 'Akash’s Apple\xa0Watch']
# steps.head()

# %% [markdown]
# ## Rolling Average

# %%
steps_by_date['RollingMeanSteps'] = steps_by_date.Steps.rolling(window=10, center=True).mean()
steps_by_date.plot(x='date', y='RollingMeanSteps', title= 'Daily step counts rolling mean over 10 days', figsize=[10, 6])
# Out:
# <AxesSubplot:title={'center':'Daily step counts rolling mean over 10 days'}, xlabel='date'>

# %% [markdown]
# ## Steps by Day of Week

# %%
steps_by_date['date'] = pd.to_datetime(steps_by_date['date'])
steps_by_date['dow'] = steps_by_date['date'].dt.weekday

# %%
data = steps_by_date.groupby(['dow'])['Steps'].mean()

fig, ax = plt.subplots(figsize=[10, 6])
ax = data.plot(kind='bar', x='day_of_week')

n_groups = len(data)
index = np.arange(n_groups)
opacity = 0.75

#fig, ax = plt.subplots(figsize=[10, 6])
ax.yaxis.grid(True)

plt.suptitle('Average Steps by Day of the Week', fontsize=16)
dow_labels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
plt.xticks(index, dow_labels, rotation=45)
plt.xlabel('Day of Week', fontsize=12, color='red')
# Out:
# Text(0.5, 0, 'Day of Week')

# %% [markdown]
# ------

# %% [markdown]
# ## Monthly Steps

# %%
total_steps_by_month = steps.groupby(['month'])['value'].sum().reset_index(name='Steps')

# %%
total_steps_by_month
# Out:
#       month   Steps
# 0   2016-06   31145
# 1   2016-07   99432
# 2   2016-08  174160
# 3   2016-09  325404
# 4   2016-10  284026
# ..      ...     ...
# 57  2021-03  294493
# 58  2021-04  257477
# 59  2021-05  192881
# 60  2021-06   81337
# 61  2021-07  246635
#
# [62 rows x 2 columns]

# %%
# a bit of a hackish solution, could use improvement
dataset = total_steps_by_month
chart_title = 'Number of Steps per month'

n_groups = len(dataset)
index = np.arange(n_groups)

ax = dataset.plot(kind='line', figsize=[12, 5], linewidth=4, alpha=1, marker='o', color='#6684c1', 
                      markeredgecolor='#6684c1', markerfacecolor='w', markersize=8, markeredgewidth=2)

# ax.set_xlim((year_counts.index[0], year_counts.index[-1]))

ax.yaxis.grid(True)
ax.xaxis.grid(True)
# ax.set_ylim(0, 1000)
ax.set_xticks(index)
ax.set_ylabel('Step Count')
# ax.set_xlabel('')
plt.xticks(index, dataset.month, rotation=90)
ax.set_title(chart_title)

plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ## Steps Per Year

# %%
total_steps_by_years = steps.groupby(['year'])['value'].sum().reset_index(name='Steps')

# %%
total_steps_by_years
# Out:
#    year    Steps
# 0  2017  3212141
# 1  2018  3849766
# 2  2019  2311753

# %%
dataset = total_steps_by_years

n_groups = len(dataset)
opacity = 0.5
fig, ax = plt.subplots(figsize=[10, 6])
ax.yaxis.grid(True)
index = np.arange(n_groups)
bar_width = 0.4

data = plt.bar(index, dataset.Steps, bar_width,
                 alpha=opacity,
                 color='c',
                 label='Steps')

data[-1].set_color('r')

plt.ylabel('Steps')
plt.title('Total Steps Per Year')
plt.xticks(index, dataset.year, rotation=45)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ## Steps by Hour of Day

# %%
hour_steps = steps.groupby(['hour'])['value'].sum().reset_index(name='Steps')

# %%
# hour_steps

# %%
ax = hour_steps.Steps.plot(kind='line', figsize=[10, 5], linewidth=4, alpha=1, marker='o', color='#6684c1', 
                      markeredgecolor='#6684c1', markerfacecolor='w', markersize=8, markeredgewidth=2)

xlabels = hour_steps.index.map(lambda x: '{:02}:00'.format(x))
ax.set_xticks(range(len(xlabels)))
ax.set_xticklabels(xlabels, rotation=45, rotation_mode='anchor', ha='right')

# ax.set_xlim((hour_steps.index[0], hour_steps.index[-1]))

ax.yaxis.grid(True)
# ax.set_ylim((0, 1300))
ax.set_ylabel('Steps')
ax.set_xlabel('')
ax.set_title('Steps by hour the day')

plt.show()

# %% [markdown]
# -----

# %%
weight = pd.read_csv("data/BodyMass.csv")

# %%
# weight.columns

# %%
# parse out date and time elements as Shanghai time
weight['startDate'] = pd.to_datetime(weight['startDate'])
weight['year'] = weight['startDate'].map(get_year)
weight['month'] = weight['startDate'].map(get_month)
weight['date'] = weight['startDate'].map(get_date)

# %%
weight.tail()
# Out:
#     sourceName sourceVersion device      type unit               creationDate  \
# 136  Shortcuts           784    NaN  BodyMass   kg  2019-07-12 23:14:18 +0800
# 137         BP         7.1.1    NaN  BodyMass   kg  2019-07-15 09:38:32 +0800
# 138  Shortcuts           788    NaN  BodyMass   kg  2019-07-28 12:04:18 +0800
# 139  Shortcuts           788    NaN  BodyMass   kg  2019-08-20 19:19:55 +0800
# 140  Shortcuts           788    NaN  BodyMass   kg  2019-09-04 21:26:04 +0800
#
#                     startDate                    endDate    value  year  \
# 136 2019-07-12 23:14:18+08:00  2019-07-12 23:14:18 +0800  79.3000  2019
# 137 2019-07-15 09:36:32+08:00  2019-07-15 09:36:32 +0800  80.5126  2019
# 138 2019-07-28 12:04:18+08:00  2019-07-28 12:04:18 +0800  80.4000  2019
# 139 2019-08-20 19:19:55+08:00  2019-08-20 19:19:55 +0800  80.0000  2019
# 140 2019-09-04 21:26:04+08:00  2019-09-04 21:26:04 +0800  80.9000  2019
#
#        month        date
# 136  2019-07  2019-07-13
# 137  2019-07  2019-07-15
# 138  2019-07  2019-07-28
# 139  2019-08  2019-08-21
# 140  2019-09  2019-09-05

# %%
month_weight = weight.groupby(['month'])['value'].mean().reset_index(name='Weight')

# %%
# month_weight

# %%
# a bit of a hackish solution, could use improvement
dataset = month_weight
chart_title = 'Monthly Weight'

n_groups = len(dataset)
index = np.arange(n_groups)

ax = dataset.plot(kind='line', figsize=[12, 5], linewidth=4, alpha=1, marker='o', color='#6684c1', 
                      markeredgecolor='#6684c1', markerfacecolor='w', markersize=8, markeredgewidth=2)

# ax.set_xlim((year_counts.index[0], year_counts.index[-1]))

ax.yaxis.grid(True)
ax.xaxis.grid(True)
# ax.set_ylim(0, 1000)
ax.set_xticks(index)
ax.set_ylabel('Weight (lbs)')
plt.xticks(index, dataset.month, rotation=90)
ax.set_title(chart_title)

plt.show()

# %%
# convert to kg
month_weight['kg'] = round(month_weight['Weight'] / 2.205, 2)

# %%
month_weight.columns
# Out:
# Index(['month', 'Weight', 'kg'], dtype='object')

# %%
# a bit of a hackish solution, could use improvement
dataset = month_weight[['month', 'kg']]
chart_title = 'Monthly Weight'

n_groups = len(dataset)
index = np.arange(n_groups)

ax = dataset.plot(kind='line', figsize=[12, 5], linewidth=4, alpha=1, marker='o', color='#6684c1', 
                      markeredgecolor='#6684c1', markerfacecolor='w', markersize=8, markeredgewidth=2)

# ax.set_xlim((year_counts.index[0], year_counts.index[-1]))

ax.yaxis.grid(True)
ax.xaxis.grid(True)
# ax.set_ylim(0, 1000)
ax.set_xticks(index)
ax.set_ylabel('Weight (kg)')
plt.xticks(index, dataset.month, rotation=90)
ax.set_title(chart_title)

plt.show()

# %% [markdown]
# ## Heart Rate

# %%
resting = pd.read_csv("data_0730/RestingHeartRate.csv")
len(resting)
# Out:
# 128

# %%
resting.columns
# Out:
# Index(['sourceName', 'sourceVersion', 'device', 'type', 'unit', 'creationDate',
#        'startDate', 'endDate', 'value'],
#       dtype='object')

# %%
resting.sourceName.unique()
# Out:
# array(['Akash’s Apple\xa0Watch'], dtype=object)

# %%
# parse out date and time elements as Shanghai time
resting['startDate'] = pd.to_datetime(resting['startDate'])
resting['year'] = resting['startDate'].map(get_year)
resting['month'] = resting['startDate'].map(get_month)
resting['date'] = resting['startDate'].map(get_date)

# %%
# resting.tail(10)

# %%
resting[resting.month == '2021-07'].plot(x='date', y='value', title= 'Resting HR', figsize=[10, 6])
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:title={'center':'Resting HR'}, xlabel='date'>

# %%
hr = pd.read_csv("data_0730/HeartRate.csv")
len(hr)
# Out:
# 154168

# %%
# hr.tail(10)

# %%
# parse out date and time elements as Shanghai time
hr['startDate'] = pd.to_datetime(hr['startDate'])
hr['year'] = hr['startDate'].map(get_year)
hr['month'] = hr['startDate'].map(get_month)
hr['hour'] = hr['startDate'].map(get_hour)
hr['date'] = hr['startDate'].map(get_date)

# %%
test_date + pd.DateOffset(1)
# Out:
# Timestamp('2021-07-29 17:00:00-0400', tz='pytz.FixedOffset(-240)')

# %%
# plot a single day
test_date = pd.to_datetime('2021-07-29 00:00:00-0400')
# len(hr[hr.date == test_date])
# TODO: Fix Axis for Hour of Day or Something Similar
# fig = plt.figure()
hr = hr.sort_values(by=['startDate'])
# hr[hr.date == test_date].plot(x='startDate', y='value', title= 'Heart Rate : %s' %(test_date), figsize=[10, 6])
# plt.xlabel('Date-Time')
# plt.ylabel('Heart Rate (bpm)')

# %%
hr_test_date = pd.DataFrame(hr[(hr.startDate > test_date) & (hr.startDate < test_date+pd.DateOffset(days=1))])
#get the sampling interval in s
hr_test_date['samplingInteval'] = pd.DataFrame(hr_test_date.startDate.diff())/np.timedelta64(1, 's')

hr_test_date = hr_test_date.rename(columns={"value": "heartRate"})

# %%
hr_test_date.plot(x='startDate', y='heartRate', title= 'Heart Rate : %s' %(test_date), figsize=[10, 6])
plt.xlabel('Date-Time')
plt.ylabel('Heart Rate (bpm)')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0, 0.5, 'Heart Rate (bpm)')

# %%
fig = plt.figure(figsize=(10,5))

ax = fig.add_subplot(211 )
ax.plot(hr_test_date.startDate, hr_test_date.heartRate, color='C0')

ax.set_ylabel('Heart Rate (bpm)')
ax.set_title('Apple Watch Data : %s' %(test_date))
ax.grid(alpha=0.4)

ax1 = fig.add_subplot(212, sharex=ax)
# ax1.plot(hr_test_date.startDate, hr_test_date.samplingInteval, color='C3')
# ax1.set_ylabel('Sampling Interval (s)')
ax1.plot(hr_test_date.startDate, 1/hr_test_date.samplingInteval, color='C3')
ax1.set_ylabel('Sampling Rate (Hz)')
ax1.set_xlabel('Date-Time')
ax1.set_yscale('log')
ax1.grid(alpha=0.4)
# ax1.set_ylim(0,20)

# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M '))
plt.gcf().autofmt_xdate()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
1/hr_test_date.samplingInteval
# Out:
# 147254         NaN
# 147255    0.028571
# 147256    0.007353
# 147257    0.002882
# 147258    0.004184
#             ...
# 154163    0.010526
# 154165    0.002488
# 154164    0.007634
# 154167    0.008475
# 154166    0.003413
# Name: samplingInteval, Length: 6897, dtype: float64

# %%
hr_test_date
# Out:
#                  sourceName sourceVersion  \
# 147526  Akash’s Apple Watch           7.6
# 147527  Akash’s Apple Watch           7.6
# 147528  Akash’s Apple Watch           7.6
# 147529  Akash’s Apple Watch           7.6
# 147530  Akash’s Apple Watch           7.6
# ...                     ...           ...
# 154163  Akash’s Apple Watch         7.6.1
# 154165  Akash’s Apple Watch         7.6.1
# 154164  Akash’s Apple Watch         7.6.1
# 154167  Akash’s Apple Watch         7.6.1
# 154166  Akash’s Apple Watch         7.6.1
#
#                                                    device       type  \
# 147526  <<HKDevice: 0x2838f3570>, name:Apple Watch, ma...  HeartRate
# 147527  <<HKDevice: 0x2838f3570>, name:Apple Watch, ma...  HeartRate
# 147528  <<HKDevice: 0x2838f3570>, name:Apple Watch, ma...  HeartRate
# 147529  <<HKDevice: 0x2838f3570>, name:Apple Watch, ma...  HeartRate
# 147530  <<HKDevice: 0x2838f3570>, name:Apple Watch, ma...  HeartRate
# ...                                                   ...        ...
# 154163  <<HKDevice: 0x283855630>, name:Apple Watch, ma...  HeartRate
# 154165  <<HKDevice: 0x283855630>, name:Apple Watch, ma...  HeartRate
# 154164  <<HKDevice: 0x283855630>, name:Apple Watch, ma...  HeartRate
# 154167  <<HKDevice: 0x283855630>, name:Apple Watch, ma...  HeartRate
# 154166  <<HKDevice: 0x283855630>, name:Apple Watch, ma...  HeartRate
#
#              unit               creationDate                 startDate  \
# 147526  count/min  2021-07-29 00:07:42 -0400 2021-07-29 00:06:38-04:00
# 147527  count/min  2021-07-29 00:12:36 -0400 2021-07-29 00:07:40-04:00
# 147528  count/min  2021-07-29 00:17:36 -0400 2021-07-29 00:16:09-04:00
# 147529  count/min  2021-07-29 00:22:36 -0400 2021-07-29 00:20:02-04:00
# 147530  count/min  2021-07-29 00:27:36 -0400 2021-07-29 00:22:39-04:00
# ...           ...                        ...                       ...
# 154163  count/min  2021-07-30 12:46:10 -0400 2021-07-30 12:37:53-04:00
# 154165  count/min  2021-07-30 12:49:20 -0400 2021-07-30 12:44:35-04:00
# 154164  count/min  2021-07-30 12:46:47 -0400 2021-07-30 12:46:46-04:00
# 154167  count/min  2021-07-30 12:55:10 -0400 2021-07-30 12:48:44-04:00
# 154166  count/min  2021-07-30 12:53:38 -0400 2021-07-30 12:53:37-04:00
#
#                           endDate  heartRate  year    month  hour        date  \
# 147526  2021-07-29 00:06:38 -0400       78.0  2021  2021-07    20  2021-07-28
# 147527  2021-07-29 00:07:40 -0400       73.0  2021  2021-07    20  2021-07-28
# 147528  2021-07-29 00:16:09 -0400       71.0  2021  2021-07    20  2021-07-28
# 147529  2021-07-29 00:20:02 -0400       72.0  2021  2021-07    20  2021-07-28
# 147530  2021-07-29 00:22:39 -0400       73.0  2021  2021-07    20  2021-07-28
# ...                           ...        ...   ...      ...   ...         ...
# 154163  2021-07-30 12:37:53 -0400       83.0  2021  2021-07     8  2021-07-30
# 154165  2021-07-30 12:44:35 -0400       98.0  2021  2021-07     8  2021-07-30
# 154164  2021-07-30 12:46:46 -0400      119.0  2021  2021-07     8  2021-07-30
# 154167  2021-07-30 12:48:44 -0400       81.0  2021  2021-07     8  2021-07-30
# 154166  2021-07-30 12:53:37 -0400      101.0  2021  2021-07     8  2021-07-30
#
#         samplingInteval
# 147526              NaN
# 147527             62.0
# 147528            509.0
# 147529            233.0
# 147530            157.0
# ...                 ...
# 154163             95.0
# 154165            402.0
# 154164            131.0
# 154167            118.0
# 154166            293.0
#
# [6625 rows x 14 columns]

# %%
temp_ = hr_test_date.samplingInteval
temp_ = temp_[~np.isnan(temp_)]
hist_count, hist_bands = np.histogram(temp_, bins=3000)

# %%
hist_bands
# Out:
# array([0.00000000e+00, 1.23746667e+01, 2.47493333e+01, ...,
#        3.70992507e+04, 3.71116253e+04, 3.71240000e+04])

# %%
hist_count = pd.Series(hist_count)
fig = plt.figure()
ax2 = plt.gca()
hist_count.plot.hist(bins=240)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
hist_count
# Out:
# array([6622,    1,    0,    0,    0,    0,    0,    0,    0,    1])

# %%
hist_bands
# Out:
# array([    0. ,  3712.4,  7424.8, 11137.2, 14849.6, 18562. , 22274.4,
#        25986.8, 29699.2, 33411.6, 37124. ])

# %% [markdown]
# ------

# %% [markdown]
# # Sleep

# %%
sleep_raw = pd.read_csv("data/SleepAnalysis.csv")

# %%
sleep_raw.tail()
# Out:
#      sourceName sourceVersion  device           type  unit  \
# 6273  AutoSleep         6.2.9     NaN  SleepAnalysis   NaN
# 6274  AutoSleep         6.2.9     NaN  SleepAnalysis   NaN
# 6275  AutoSleep         6.2.9     NaN  SleepAnalysis   NaN
# 6276  AutoSleep         6.2.9     NaN  SleepAnalysis   NaN
# 6277  AutoSleep         6.2.9     NaN  SleepAnalysis   NaN
#
#                    creationDate                  startDate  \
# 6273  2019-09-06 10:06:23 +0800  2019-09-06 03:01:00 +0800
# 6274  2019-09-07 09:46:44 +0800  2019-09-07 03:15:00 +0800
# 6275  2019-09-07 09:46:44 +0800  2019-09-07 03:15:00 +0800
# 6276  2019-09-08 10:33:08 +0800  2019-09-08 00:45:00 +0800
# 6277  2019-09-08 10:33:08 +0800  2019-09-08 00:45:00 +0800
#
#                         endDate                               value
# 6273  2019-09-06 09:59:00 +0800  HKCategoryValueSleepAnalysisAsleep
# 6274  2019-09-07 09:42:00 +0800   HKCategoryValueSleepAnalysisInBed
# 6275  2019-09-07 09:42:00 +0800  HKCategoryValueSleepAnalysisAsleep
# 6276  2019-09-08 10:27:00 +0800   HKCategoryValueSleepAnalysisInBed
# 6277  2019-09-08 10:27:00 +0800  HKCategoryValueSleepAnalysisAsleep

# %%
# parse out date and time elements as Shanghai time
steps['startDate'] = pd.to_datetime(steps['startDate'])
steps['year'] = steps['startDate'].map(get_year)
steps['month'] = steps['startDate'].map(get_month)
steps['date'] = steps['startDate'].map(get_date)
steps['day'] = steps['startDate'].map(get_day)
steps['hour'] = steps['startDate'].map(get_hour)
steps['dow'] = steps['startDate'].map(get_day_of_week)
